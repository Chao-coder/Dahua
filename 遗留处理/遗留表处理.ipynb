# %%
#libraries we are going to use
import numpy as np # linear algebra
import pandas as pd # data processing
from plotly.offline import iplot, init_notebook_mode #visualization
import plotly.express as px #visualization
from plotly.subplots import make_subplots #visualization
import plotly.graph_objects as go #visualization
import matplotlib.pyplot as plt #visualization
import seaborn as sns #visualization
from sklearn import preprocessing #label encoder 
from sklearn.model_selection import train_test_split #split data
from sklearn.linear_model import LogisticRegression #model
from sklearn.model_selection import cross_val_score #cross validation
from sklearn.metrics import classification_report #reports 
from sklearn import metrics #confusion metrics
from sklearn.model_selection import GridSearchCV #get best parameters

# %%
#import the filenames
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# convert file into dataset
# data = pd.read_csv('/content/wcc.csv')
data = pd.read_excel('/content/0524遗留明细-DY.xlsx')
# data = pd.read_csv('/content/0519.csv')

# %%
#explore first five rows in the dataset
data.head()
# Out:
#                     PI号  制单人        创建日期        排产日期            订单号 一生二标识  \
# 0  C2762772303101D9963A  胡春思  2023-03-13  2023-03-13  2023031300139     N
# 1  C2762772303101D9963A  胡春思  2023-04-25  2023-04-25  2023042500191     N
# 2  C2762772303101D9963A  胡春思  2023-04-03  2023-04-03  2023040300019     N
# 3  C2762772303101D9963A  胡春思  2023-03-31  2023-03-31  2023033100028     N
# 4  C2762772303101D9963A  胡春思  2023-03-31  2023-03-31  2023033100028     N
#
#    一生二订单号   辖区     组别 业绩归属国  ...                 预计船期               预计出库日期  \
# 0     NaN  俄语区  运营管理组  亚美尼亚  ...  2023/05/27 16:00:00  2023/05/24 00:00:00
# 1     NaN  俄语区  分销业务部  亚美尼亚  ...  2023/05/27 16:00:00  2023/05/24 00:00:00
# 2     NaN  俄语区  分销业务部  亚美尼亚  ...  2023/05/27 16:00:00  2023/05/24 00:00:00
# 3     NaN  俄语区  分销业务部  亚美尼亚  ...  2023/05/27 16:00:00  2023/05/24 00:00:00
# 4     NaN  俄语区  分销业务部  亚美尼亚  ...  2023/05/27 16:00:00  2023/05/24 00:00:00
#
#   行总金额USD  发货计划   付款条件 返工标识               原始需求日期 排产意见                 产品系列  \
# 0    6096  凑柜发货  OA 90  NaN  2023-03-25 00:00:00  NaN          VTH5 Series
# 1     482  凑柜发货  OA 90  NaN  2023-05-20 00:00:00  NaN            KT Series
# 2   40200  凑柜发货  OA 90  NaN  2023-04-15 00:00:00  NaN          SD49 Series
# 3    3864  凑柜发货  OA 90  NaN  2023-04-15 00:00:00  NaN          VTO3 Series
# 4    6544  凑柜发货  OA 90  NaN  2023-04-15 00:00:00  NaN  Hardened PoE Switch
#
#                产品主型号
# 0        VTH5221D-S2
# 1              KTA02
# 2          SD49225ZB
# 3        VTO3211D-S2
# 4  PFS3106-4ET-60-V2
#
# [5 rows x 111 columns]

# %%
#information about dataset, type, columns names, null 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Columns: 111 entries, PI号 to 产品主型号
# dtypes: datetime64[ns](1), float64(32), int64(10), object(68)
# memory usage: 1.1+ MB

# %%
df = data[['实际交易客户','业务员','客户PO号','物料编码','内部型号','规格型号','订单行数量','单价','行合计','币种','状态','统筹交期','彩盒Box Weight (kg), ','彩盒Box Volume(m³)','每箱台数Pcs/Carton','毛件体（长度）','毛件体（宽度）','毛件体（高度）','毛件体（体积）',]]

# %%
业务员 = df['业务员'].unique()
业务员
# Out:
# array(['程思', '黄伟杰', '赵安然', 'Tsvetkov Pavel', '孙世林', '汪喆', '李嘉慧',
#        'Kachalin Maxim', '纪洋', '杨宇', '王昱周', '李杨'], dtype=object)

# %%
df.head()
# Out:
#     实际交易客户 业务员        客户PO号                  物料编码                  内部型号  \
# 0  Mercury  程思  ML202301-02  1.0.01.15.11062-0024      DHI-VTH5221DW-S2
# 1  Mercury  程思  ML202301-02  1.0.01.15.11509-0061             DHI-KTA02
# 2  Mercury  程思  ML202301-02  1.0.01.07.13754-0001     DH-SD49225-HNR-ZB
# 3  Mercury  程思  ML202301-02  1.0.01.15.11384-0016    DHI-VTO3211D-P1-S2
# 4  Mercury  程思  ML202301-02  1.0.01.20.10614-0019  DH-PFS3106-4ET-60-V2
#
#                   规格型号  订单行数量     单价      行合计   币种  状态        统筹交期  \
# 0     DHI-VTH5221DW-S2     80   76.2   6096.0  USD  入库  2023-05-15
# 1            DHI-KTA02     10   48.2    482.0  USD  入库  2023-05-23
# 2  DH-SD49225XA-HNR-S2    200  201.0  40200.0  USD  入库  2023-04-30
# 3      DHI-VTO3211D-P1     60   64.4   3864.0  USD  入库  2023-05-06
# 4    DH-PFS3106-4ET-60    160   40.9   6544.0  USD  入库  2023-04-30
#
#    彩盒Box Weight (kg),   彩盒Box Volume(m³)  每箱台数Pcs/Carton  毛件体（长度）  毛件体（宽度）  \
# 0                 0.78          0.005868              10    0.774    0.324
# 1                 1.02          0.006739              10    0.585    0.320
# 2                 4.84          0.031438               1    0.267    0.267
# 3                 0.74          0.003739              10    0.424    0.323
# 4                 1.15          0.005747               8    0.549    0.253
#
#    毛件体（高度）   毛件体（体积）
# 0    0.234  0.058682
# 1    0.360  0.067392
# 2    0.441  0.031438
# 3    0.273  0.037388
# 4    0.331  0.045975

# %%
# 通过.loc 筛选出某一列中的其中多项子项
王昱周 = df.loc[df['业务员'].isin(['王昱周','杨宇'])]
王昱周.head()
# Out:
#       实际交易客户 业务员         客户PO号                  物料编码  \
# 767  Jupiter  杨宇  DH-TR2023001       1.0.01.04.41025
# 768  Jupiter  杨宇  DH-TR2023001  1.0.01.34.13055-9002
# 769  Jupiter  杨宇  DH-TR2023001       1.0.99.12.10062
# 770  Jupiter  杨宇  DH-TR2023001       1.0.01.20.11055
# 771  Jupiter  杨宇  DH-TR2023001       1.0.01.20.10728
#
#                                         内部型号                           规格型号  \
# 767  DH-IPC-HFW5442HP-ZHE-2712F-DC12AC24V-S3            DH-IPC-HFW5442H-ZHE
# 768            DHI-TPC-SDA8641-B50Z45-BM-S22  DHI-TPC-SDA8641-B50Z45-BM-S22
# 769                         DHI-LM24-F200-C4                  DHI-LM24-F200
# 770                        DH-IS4210-8GT-120              DH-IS4210-8GT-120
# 771                   DH-PFS4218-16ET-240-V3            DH-PFS4218-16ET-240
#
#      订单行数量      单价      行合计   币种  状态        统筹交期  彩盒Box Weight (kg),   \
# 767     92   160.0  14720.0  USD  入库  2023-05-15                3.010
# 768      5  4500.0  22500.0  USD  入库  2023-05-20               21.020
# 769     25    75.0   1875.0  USD  入库  2023-04-15                4.143
# 770     27   175.0   4725.0  USD  入库  2023-04-23                1.410
# 771      1   120.0    120.0  USD  入库  2023-04-20                4.700
#
#      彩盒Box Volume(m³)  每箱台数Pcs/Carton  毛件体（长度）  毛件体（宽度）  毛件体（高度）   毛件体（体积）
# 767          0.019379               6    0.635    0.451    0.406  0.116272
# 768          0.156043               1    0.580    0.380    0.708  0.156043
# 769          0.039000               1    0.602    0.116    0.490  0.034218
# 770          0.005656              20    0.530    0.396    0.539  0.113125
# 771          0.028599               5    0.584    0.549    0.446  0.142995

# %%
程思 = df[df['业务员']=='程思']
黄伟杰 = df[df['业务员']=='黄伟杰']
赵安然 = df[df['业务员']=='赵安然']
TP = df[df['业务员']=='Tsvetkov Pavel']
孙世林 = df[df['业务员']=='孙世林']
汪喆 = df[df['业务员']=='汪喆']
李嘉慧 = df[df['业务员']=='李嘉慧']
KM = df[df['业务员']=='Kachalin Maxim']
纪洋 = df[df['业务员']=='纪洋']
# 杨宇 = df[df['业务员']=='杨宇']
王昱周 = df[df['业务员']=='王昱周']
李杨 = df[df['业务员']=='李杨']

# %%
黄伟杰.head()
# Out:
#        实际交易客户  业务员      客户PO号                 物料编码             内部型号  \
# 246  Saturn-0  黄伟杰  ST0223003      1.5.01.98.31110  DHI-PHSJG-FFF-P
# 247  Saturn-0  黄伟杰  ST0223003      1.1.02.08.14724  LS550UD/E-E/U-Y
# 248  Saturn-0  黄伟杰  ST0223003      1.5.01.98.31104  DHI-PHSJG-FFF-P
# 249  Saturn-0  黄伟杰  ST0223003      1.0.01.01.15170   DHI-DS04-AI400
# 250  Saturn-0  黄伟杰  ST0223003  1.2.51.34.10232-000              NaN
#
#                 规格型号  订单行数量     单价    行合计   币种  状态        统筹交期  \
# 246  DHI-PHSJG-FFF-P      1  285.0  285.0  USD  入库  2023-04-20
# 247  LS550UD/E-E/U-Y      2  126.0  252.0  USD  入库  2023-05-31
# 248  DHI-PHSJG-FFF-P      1  285.0  285.0  USD  入库  2023-04-20
# 249   DHI-DS04-AI400      2   84.0  168.0  USD  入库  2023-04-05
# 250         LS650-X2      2   43.2   86.4  USD  在制  2023-05-31
#
#      彩盒Box Weight (kg),   彩盒Box Volume(m³)  每箱台数Pcs/Carton  毛件体（长度）  毛件体（宽度）  \
# 246                10.00          0.500000               0    0.000    0.000
# 247                12.50          0.199430               0    0.000    0.000
# 248                10.00          0.500000               0    0.000    0.000
# 249                 0.87          0.005747               8    0.549    0.253
# 250                20.00          1.219680               0    1.763    0.628
#
#      毛件体（高度）   毛件体（体积）
# 246    0.000  0.000000
# 247    0.000  0.000000
# 248    0.000  0.000000
# 249    0.331  0.045975
# 250    1.209  1.338561

# %%
import time
date = time.strftime('%Y_%m_%d',time.localtime())
print(date)
type(date)
# Out:
# 2023_05_25
# str

# %%
# 存储路径及文件名

filename = "date.xlsx"
directory = "/content/"
file_savepath = directory + filename + date
print(file_savepath)
# Out:
# /content/date.xlsx2023_05_25

# %%
# 黄伟杰.to_csv('hwj.csv')/content/0524遗留明细-DY.xlsx
程思.to_excel('/content/程思0524.xlsx')
黄伟杰.to_excel('/content/黄伟杰0524.xlsx')
赵安然.to_excel('/content/赵安然0524.xlsx')
TP.to_excel('/content/Tsvetkov Pavel_0524.xlsx')
孙世林.to_excel('/content/孙世林0524.xlsx')
汪喆.to_excel('/content/汪喆0524.xlsx')
李嘉慧.to_excel('/content/李嘉慧0524.xlsx')
KM.to_excel('/content/Kachalin Maxim_0524.xlsx')
纪洋.to_excel('/content/纪洋0524.xlsx')
# 杨宇.to_excel('/content/0524遗留表/杨宇0524.xlsx')
王昱周.to_excel('/content/王昱周0524.xlsx')
李杨.to_excel('/content/李杨0524.xlsx')
